# %%
import os

import ast
import intake

from ecgtools import Builder
from ecgtools.parsers.cesm import parse_cesm_history

# %%
archive = '/glade/scratch/mclong/archive'

data_info = dict(
    ctrl=dict(
        casename='g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005',
        histpath='/glade/campaign/cesm/development/espwg/SMYLE/initial_conditions/SMYLE-FOSI/',
    ),
)

runs = [
    'g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.PCref2x', 
#    'g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.PCref1.5x',
#    'g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.PCref1.2x',
]
        
        
data_info.update(
    {k.split('.')[-1]: dict(casename=k, histpath=f'{archive}/{k}')
    for k in runs}
)
data_info
# Out:
# {'ctrl': {'casename': 'g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005',
#   'histpath': '/glade/campaign/cesm/development/espwg/SMYLE/initial_conditions/SMYLE-FOSI/'},
#  'PCref2x': {'casename': 'g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.PCref2x',
#   'histpath': '/glade/scratch/mclong/archive/g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.PCref2x'}}

# %%
b = Builder(
    data_info["ctrl"]["histpath"],
    depth=1,
    exclude_patterns=["*/rest/*", "*/logs/*", "*/proc/*"],
    njobs=5,
)
b = b.build( 
    parse_cesm_history,
)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 604 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=5)]: Done 756 out of 756 | elapsed:    0.7s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   8 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=5)]: Done  62 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=5)]: Done 152 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=5)]: Done 278 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=5)]: Done 638 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=5)]: Done 872 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=5)]: Done 1142 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=5)]: Done 1448 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=5)]: Done 1790 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=5)]: Done 2168 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=5)]: Done 2582 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=5)]: Done 3032 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=5)]: Done 3518 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=5)]: Done 4040 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=5)]: Done 4598 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=5)]: Done 5192 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=5)]: Done 5822 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=5)]: Done 6015 out of 6015 | elapsed: 12.7min finished

# %%
os.makedirs("catalogs", exist_ok=True)
b.save(
    "catalogs/smyle-fosi-ctrl.csv.gz",
    path_column_name='path',
    variable_column_name='variables',
    data_format="netcdf",
    groupby_attrs=["component", "stream", "case"],
    aggregations=[
        {
            "type": "join_existing",
            "attribute_name": "date",
            "options": {"dim": "time", "coords": "minimal", "compat": "override"},
        }
    ],
)
# Out:
# Saved catalog location: catalogs/smyle-fosi-ctrl.csv.json and catalogs/smyle-fosi-ctrl.csv.gz

# %%
cat = intake.open_esm_datastore(
    'catalogs/smyle-fosi-ctrl.csv.json',
    csv_kwargs={"converters": {"variables": ast.literal_eval}},
)
cat
# Out:
# <p><strong>None catalog with 5 dataset(s) from 6015 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>component</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>date</th>
#       <td>5235</td>
#     </tr>
#     <tr>
#       <th>case</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variables</th>
#       <td>620</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>6015</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat_sub = cat.search(variables='FG_CO2')
cat_sub.df
# Out:
#     component stream     date  \
# 0         ocn  pop.h  0306-01
# 1         ocn  pop.h  0306-02
# 2         ocn  pop.h  0306-03
# 3         ocn  pop.h  0306-04
# 4         ocn  pop.h  0306-05
# ..        ...    ...      ...
# 751       ocn  pop.h  0368-08
# 752       ocn  pop.h  0368-09
# 753       ocn  pop.h  0368-10
# 754       ocn  pop.h  0368-11
# 755       ocn  pop.h  0368-12
#
#                                                   case  member_id frequency  \
# 0    g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 1    g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 2    g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 3    g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 4    g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# ..                                                 ...        ...       ...
# 751  g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 752  g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 753  g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 754  g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
# 755  g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE...          5   month_1
#
#                                              variables  \
# 0    [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 1    [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 2    [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 3    [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 4    [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# ..                                                 ...
# 751  [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 752  [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 753  [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 754  [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
# 755  [UVEL, UVEL2, VVEL, VVEL2, TEMP, dTEMP_POS_2D,...
#
#                                                   path
# 0    /glade/campaign/cesm/development/espwg/SMYLE/i...
# 1    /glade/campaign/cesm/development/espwg/SMYLE/i...
# 2    /glade/campaign/cesm/development/espwg/SMYLE/i...
# 3    /glade/campaign/cesm/development/espwg/SMYLE/i...
# 4    /glade/campaign/cesm/development/espwg/SMYLE/i...
# ..                                                 ...
# 751  /glade/campaign/cesm/development/espwg/SMYLE/i...
# 752  /glade/campaign/cesm/development/espwg/SMYLE/i...
# 753  /glade/campaign/cesm/development/espwg/SMYLE/i...
# 754  /glade/campaign/cesm/development/espwg/SMYLE/i...
# 755  /glade/campaign/cesm/development/espwg/SMYLE/i...
#
# [756 rows x 8 columns]

# %%
cdf_kwargs=dict(
    use_cftime=True, 
    chunks={'time': 12},
)
dsets = cat_sub.to_dataset_dict(cdf_kwargs=cdf_kwargs)
dsets
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.stream.case'
# █
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/merge_util.py in _open_asset(path, data_format, zarr_kwargs, cdf_kwargs, preprocess, varname, requested_variables)
#     291         try:
# --> 292             ds = xr.open_dataset(path, **cdf_kwargs)
#     293         except Exception as exc:
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     500         **decoders,
# --> 501         **kwargs,
#     502     )
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     572                 use_cftime=use_cftime,
# --> 573                 decode_timedelta=decode_timedelta,
#     574             )
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/store.py in open_dataset(self, store, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      23     ):
# ---> 24         vars, attrs = store.load()
#      25         encoding = store.get_encoding()
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/common.py in load(self)
#     123         variables = FrozenDict(
# --> 124             (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     125         )
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in get_variables(self)
#     421         return FrozenDict(
# --> 422             (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     423         )
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/core/utils.py in FrozenDict(*args, **kwargs)
#     476 def FrozenDict(*args, **kwargs) -> Frozen:
# --> 477     return Frozen(dict(*args, **kwargs))
#     478
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in <genexpr>(.0)
#     421         return FrozenDict(
# --> 422             (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     423         )
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open_store_variable(self, name, var)
#     391     def open_store_variable(self, name, var):
# --> 392         dimensions = var.dimensions
#     393         data = indexing.LazilyIndexedArray(NetCDF4ArrayWrapper(name, self))
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.dimensions.__get__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable._getdims()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# RuntimeError: NetCDF: Not a valid ID
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# /glade/scratch/mclong/tmp/ipykernel_208970/3882166551.py in <module>
#       3     chunks={'time': 12},
#       4 )
# ----> 5 dsets = cat_sub.to_dataset_dict(cdf_kwargs=cdf_kwargs)
#       6 dsets
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/core.py in to_dataset_dict(self, zarr_kwargs, cdf_kwargs, preprocess, storage_options, progressbar, aggregate)
#     920             ]
#     921             for i, task in enumerate(concurrent.futures.as_completed(future_tasks)):
# --> 922                 key, ds = task.result()
#     923                 self._datasets[key] = ds
#     924                 if self.progressbar:
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     426                 raise CancelledError()
#     427             elif self._state == FINISHED:
# --> 428                 return self.__get_result()
#     429
#     430             self._condition.wait(timeout)
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/core.py in _load_source(key, source)
#     906
#     907         def _load_source(key, source):
# --> 908             return key, source.to_dask()
#     909
#     910         sources = {key: source(**source_kwargs) for key, source in self.items()}
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/source.py in to_dask(self)
#     243     def to_dask(self):
#     244         """Return xarray object (which will have chunks)"""
# --> 245         self._load_metadata()
#     246         return self._ds
#     247
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake/source/base.py in _load_metadata(self)
#     234         """load metadata only if needed"""
#     235         if self._schema is None:
# --> 236             self._schema = self._get_schema()
#     237             self.dtype = self._schema.dtype
#     238             self.shape = self._schema.shape
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/source.py in _get_schema(self)
#     172
#     173         if self._ds is None:
# --> 174             self._open_dataset()
#     175
#     176             metadata = {
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/source.py in _open_dataset(self)
#     224             for _, row in self.df.iterrows()
#     225         ]
# --> 226         datasets = dask.compute(*datasets)
#     227         mapper_dict = dict(datasets)
#     228         nd = create_nested_dict(self.df, self.path_column, self.aggregation_columns)
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     566         postcomputes.append(x.__dask_postcompute__())
#     567
# --> 568     results = schedule(dsk, keys, **kwargs)
#     569     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     570
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      85         get_id=_thread_get_id,
#      86         pack_exception=pack_exception,
# ---> 87         **kwargs
#      88     )
#      89
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     515                             _execute_task(task, data)  # Re-execute locally
#     516                         else:
# --> 517                             raise_exception(exc, tb)
#     518                     res, worker_id = loads(res_info)
#     519                     state["cache"][key] = res
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask/local.py in reraise(exc, tb)
#     323     if exc.__traceback__ is not tb:
#     324         raise exc.with_traceback(tb)
# --> 325     raise exc
#     326
#     327
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     221     try:
#     222         task, data = loads(task_info)
# --> 223         result = _execute_task(task, data)
#     224         id = get_id()
#     225         result = dumps((result, id))
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/source.py in read_dataset(path, data_format, storage_options, cdf_kwargs, zarr_kwargs, preprocess, varname)
#     208                 preprocess=preprocess,
#     209                 varname=varname,
# --> 210                 requested_variables=self.requested_variables,
#     211             )
#     212             return (path, ds)
#
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/intake_esm/merge_util.py in _open_asset(path, data_format, zarr_kwargs, cdf_kwargs, preprocess, varname, requested_variables)
#     307             ********************************************
#     308             """
# --> 309             raise IOError(message) from exc
#     310     if preprocess is not None:
#     311         try:
#
# OSError:
#             Failed to open netCDF/HDF dataset.
#
#             *** Arguments passed to xarray.open_dataset() ***:
#
#             - filename_or_obj: /glade/campaign/cesm/development/espwg/SMYLE/initial_conditions/SMYLE-FOSI/ocn/hist/g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.pop.h.0350-04.nc
#             - kwargs: {'use_cftime': True, 'chunks': {'time': 12}}
#
#             *** fsspec options used ***:
#
#             - root: /glade/campaign/cesm/development/espwg/SMYLE/initial_conditions/SMYLE-FOSI/ocn/hist/g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.pop.h.0350-04.nc
#             - protocol: None
#
#             ********************************************

# %%
import xarray as xr

# %%
ds = xr.open_dataset("/glade/campaign/cesm/development/espwg/SMYLE/initial_conditions/SMYLE-FOSI/ocn/hist/g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.pop.h.0350-04.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:                          (time: 1, d2: 2, moc_comp: 3, transport_comp: 5, transport_reg: 2, z_t: 60, z_t_150m: 15, z_w: 60, z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395, moc_z: 61, nlat: 384, nlon: 320)
# Coordinates: (12/14)
#     transport_components             (transport_comp) |S384 ...
#     transport_regions                (transport_reg) |S384 ...
#   * time                             (time) object 0350-05-01 00:00:00
#   * z_t                              (z_t) float32 500.0 1.5e+03 ... 5.375e+05
#   * z_t_150m                         (z_t_150m) float32 500.0 ... 1.45e+04
#   * z_w                              (z_w) float32 0.0 1e+03 ... 5e+05 5.25e+05
#     ...                               ...
#   * lat_aux_grid                     (lat_aux_grid) float32 -79.49 ... 90.0
#   * moc_z                            (moc_z) float32 0.0 1e+03 ... 5.5e+05
#     ULONG                            (nlat, nlon) float64 ...
#     ULAT                             (nlat, nlon) float64 ...
#     TLONG                            (nlat, nlon) float64 ...
#     TLAT                             (nlat, nlon) float64 ...
# Dimensions without coordinates: d2, moc_comp, transport_comp, transport_reg, nlat, nlon
# Data variables: (12/498)
#     time_bound                       (time, d2) object ...
#     moc_components                   (moc_comp) |S384 ...
#     dz                               (z_t) float32 ...
#     dzw                              (z_w) float32 ...
#     KMT                              (nlat, nlon) float64 ...
#     KMU                              (nlat, nlon) float64 ...
#     ...                               ...
#     XBLT                             (time, nlat, nlon) float32 ...
#     TBLT                             (time, nlat, nlon) float32 ...
#     BSF                              (time, nlat, nlon) float32 ...
#     MOC                              (time, transport_reg, moc_comp, moc_z, lat_aux_grid) float32 ...
#     N_HEAT                           (time, transport_reg, transport_comp, lat_aux_grid) float32 ...
#     N_SALT                           (time, transport_reg, transport_comp, lat_aux_grid) float32 ...
# Attributes:
#     title:             g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
#     history:           none
#     Conventions:       CF-1.0; http://www.cgd.ucar.edu/cms/eaton/netcdf/CF-cu...
#     time_period_freq:  month_1
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     contents:          Diagnostic and Prognostic Variables
#     source:            CCSM POP2, the CCSM Ocean Component
#     revision:          $Id$
#     calendar:          All years have exactly  365 days.
#     start_time:        This dataset was created on 2020-11-06 at 01:27:53.7
#     cell_methods:      cell_methods = time: mean ==> the variable values are ...
